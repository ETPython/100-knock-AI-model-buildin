# %% [markdown]
# <a href="https://colab.research.google.com/github/ETPython/100-knock-AI-model-buildin/blob/master/Stable_Diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://note.com/npaka/n/ndd549d2ce556

# %% [markdown]
# https://huggingface.co/CompVis/stable-diffusion-v1-4

# %% [markdown]
# mail:a11121112a2000@yahoo.co.jp<br>
# pass:a11121112A

# %%
# パッケージのインストール
# !pip install diffusers==0.2.4 transformers scipy ftfy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 112 kB 14.8 MB/s
# ...
#      |████████████████████████████████| 5.3 MB 60.8 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 163 kB 72.9 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 55.9 MB/s
# ...

# %%
# トークン変数の準備
YOUR_TOKEN="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"

# %%
from diffusers import StableDiffusionPipeline

# StableDiffusionパイプラインの準備
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", use_auth_token=YOUR_TOKEN)
pipe.to("cuda")
# Out:
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/209 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/230 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/592 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# ...

# %%
# 画像生成
prompt = "car,future"
image = pipe(prompt)["sample"][0]
image.save(f"car.png")
# Out:
# 0it [00:00, ?it/s]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img=plt.imshow(image)
